# %%
import pandas as pd

# %%
pd.read_csv('/Users/mayukhsarkar/Desktop/wc_players.csv')
# Out:
#                    Player      ID      Country
# 0       Gulbadin Naib (c)  352048  Afghanistan
# 1        Rashid Khan (vc)  793463  Afghanistan
# 2              Aftab Alam  440963  Afghanistan
# 3           Asghar Afghan  320652  Afghanistan
# 4           Dawlat Zadran  516561  Afghanistan
# ..                    ...     ...          ...
# 147          Ashley Nurse  315594   WestIndies
# 148  Nicholas Pooran (wk)  604302   WestIndies
# 149           Kemar Roach  230553   WestIndies
# 150         Andre Russell  276298   WestIndies
# 151         Oshane Thomas  914567   WestIndies
#
# [152 rows x 3 columns]

# %%
players=pd.read_csv('/Users/mayukhsarkar/Desktop/wc_players.csv')

# %%
pd.read_csv('/Users/mayukhsarkar/Desktop/ground_averages.csv')
# Out:
#                                                 Ground       Span  Mat  Won  \
# 0                        Eden Gardens, Kolkata - India  2013-2017    4    4
# 1                      Feroz Shah Kotla, Delhi - India  2013-2019    4    4
# 2                 Melbourne Cricket Ground - Australia  2013-2019   15   15
# 3    Saurashtra Cricket Association Stadium, Rajkot...  2013-2015    2    2
# 4                            Adelaide Oval - Australia  2013-2019   10   10
# ..                                                 ...        ...  ...  ...
# 101  Greenfield International Stadium, Thiruvananth...  2018-2018    1    1
# 102  Sylhet International Cricket Stadium - Bangladesh  2018-2018    1    1
# 103  Rajiv Gandhi International Cricket Stadium, De...  2019-2019    5    4
# 104       Wanderers Cricket Ground, Windhoek - Namibia  2019-2019    1    1
# 105                    Affies Park, Windhoek - Namibia  2019-2019    1    1
#
#      Tied  NR  Runs  Wkts  Balls    Ave   RPO
# ...

# %%
ground_data=pd.read_csv('/Users/mayukhsarkar/Desktop/ground_averages.csv')

# %%
pd.read_csv('/Users/mayukhsarkar/Desktop/batsman.csv')
# Out:
#        Unnamed: 0  Bat1 Runs  BF     SR 4s 6s    Opposition     Ground  \
# 0               1   DNB    -   -      -  -  -       v India     Nagpur
# 1               2   DNB    -   -      -  -  -       v India    Kolkata
# 2               3   DNB    -   -      -  -  -       v India      Delhi
# 3               4   DNB    -   -      -  -  -  v Bangladesh      Dhaka
# 4               5   DNB    -   -      -  -  -       v India      Dhaka
# ...           ...   ...  ...  ..    ... .. ..           ...        ...
# 11144       11145    46   46  61  75.40  6  1     v Ireland   Dehradun
# 11145       11146     3    3   6  50.00  0  0     v Ireland   Dehradun
# 11146       11147     1    1   8  12.50  0  0     v Ireland   Dehradun
# 11147       11148   DNB    -   -      -  -  -    v Scotland  Edinburgh
# 11148       11149  TDNB    -   -      -  -  -     v Ireland    Belfast
#
#         Start Date    Match_ID         Batsman  Player_ID
# ...

# %%
batsman=pd.read_csv('/Users/mayukhsarkar/Desktop/batsman.csv')

# %%
pd.read_csv('/Users/mayukhsarkar/Desktop/bowler.csv')
# Out:
#        Unnamed: 0 Overs Mdns Runs Wkts   Econ    Ave    SR    Opposition  \
# 0               1   8.0    0   57    0   7.12      -     -       v India
# 1               2  10.0    0   55    2   5.50  27.50  30.0       v India
# 2               3     -    -    -    -      -      -     -       v India
# 3               4   9.0    1   63    2   7.00  31.50  27.0  v Bangladesh
# 4               5   8.0    1   48    0   6.00      -     -       v India
# ...           ...   ...  ...  ...  ...    ...    ...   ...           ...
# 11113       11114   4.0    0   41    0  10.25      -     -       v India
# 11114       11115   7.2    0   20    2   2.72  10.00  22.0     v Ireland
# 11115       11116     -    -    -    -      -      -     -     v Ireland
# 11116       11117   6.0    0   21    1   3.50  21.00  36.0     v Ireland
# 11117       11118  10.0    0   72    3   7.20  24.00  20.0    v Scotland
#
#             Ground   Start Date    Match_ID          Bowler  Player_ID
# ...

# %%
bowler=pd.read_csv('/Users/mayukhsarkar/Desktop/bowler.csv')

# %%
pd.read_csv('/Users/mayukhsarkar/Desktop/odi_match_totals.csv')
# Out:
#       Unnamed: 0  Score  Overs   RPO  Target  Inns Result   Opposition  \
# 0            412    250   48.3  5.15     NaN     1    won      v India
# 1            680    165   48.0  3.43   251.0     2   lost   v Pakistan
# 2            413    157   48.5  3.21   168.0     2   lost      v India
# 3            681    167   43.4  3.82     NaN     1    won   v Pakistan
# 4            117    198   40.0  4.95   306.0     2   lost  v Australia
# ...          ...    ...    ...   ...     ...   ...    ...          ...
# 1291         549  340/7   50.0  6.80     NaN     1   lost    v England
# 1292         979  341/7   49.3  6.88   341.0     2    won   v Pakistan
# 1293        1296  120/8   33.0  3.63   211.0     2      -    v Ireland
# 1294         550  193/6   31.5  6.06   352.0     2      -    v England
# 1295         980  351/9   50.0  7.02     NaN     1      -   v Pakistan
#
#           Ground   Start Date    Match_ID      Country  Country_ID
# ...

# %%
odi_match_total=pd.read_csv('/Users/mayukhsarkar/Desktop/odi_match_totals.csv')

# %%
players.head(10)
# Out:
#                   Player      ID      Country
# 0      Gulbadin Naib (c)  352048  Afghanistan
# 1       Rashid Khan (vc)  793463  Afghanistan
# 2             Aftab Alam  440963  Afghanistan
# 3          Asghar Afghan  320652  Afghanistan
# 4          Dawlat Zadran  516561  Afghanistan
# 5           Hamid Hassan  311427  Afghanistan
# 6   Hashmatullah Shahidi  440970  Afghanistan
# 7      Hazratullah Zazai  793457  Afghanistan
# 8          Mohammad Nabi   25913  Afghanistan
# 9  Mohammad Shahzad (wk)  419873  Afghanistan

# %%
players['Country']=="India"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 147    False
# 148    False
# 149    False
# 150    False
# 151    False
# Name: Country, Length: 152, dtype: bool

# %%
players[players['Country']=="India"]
# Out:
#                Player      ID Country
# 61    Virat Kohli (c)  253802   India
# 62  Rohit Sharma (vc)   34102   India
# 63     Shikhar Dhawan   28235   India
# 64        K. L. Rahul  422108   India
# 65      Vijay Shankar  477021   India
# 66      MS Dhoni (wk)   28081   India
# 67       Kedar Jadhav  290716   India
# 68     Dinesh Karthik   30045   India
# 69   Yuzvendra Chahal  430246   India
# 70      Kuldeep Yadav  559235   India
# 71  Bhuvneshwar Kumar  326016   India
# 72     Jasprit Bumrah  625383   India
# 73      Hardik Pandya  625371   India
# 74    Ravindra Jadeja  234675   India
# 75     Mohammed Shami  481896   India

# %%
indian_players=players[players['Country']=="India"]

# %%
indian_players
# Out:
#                Player      ID Country
# 61    Virat Kohli (c)  253802   India
# 62  Rohit Sharma (vc)   34102   India
# 63     Shikhar Dhawan   28235   India
# 64        K. L. Rahul  422108   India
# 65      Vijay Shankar  477021   India
# 66      MS Dhoni (wk)   28081   India
# 67       Kedar Jadhav  290716   India
# 68     Dinesh Karthik   30045   India
# 69   Yuzvendra Chahal  430246   India
# 70      Kuldeep Yadav  559235   India
# 71  Bhuvneshwar Kumar  326016   India
# 72     Jasprit Bumrah  625383   India
# 73      Hardik Pandya  625371   India
# 74    Ravindra Jadeja  234675   India
# 75     Mohammed Shami  481896   India

# %%
odi_match_total.head()
# Out:
#    Unnamed: 0 Score  Overs   RPO  Target  Inns Result   Opposition     Ground  \
# 0         412   250   48.3  5.15     NaN     1    won      v India    Kolkata
# 1         680   165   48.0  3.43   251.0     2   lost   v Pakistan    Kolkata
# 2         413   157   48.5  3.21   168.0     2   lost      v India      Delhi
# 3         681   167   43.4  3.82     NaN     1    won   v Pakistan      Delhi
# 4         117   198   40.0  4.95   306.0     2   lost  v Australia  Melbourne
#
#     Start Date    Match_ID   Country  Country_ID
# 0   3 Jan 2013  ODI # 3315  Pakistan           7
# 1   3 Jan 2013  ODI # 3315     India           6
# 2   6 Jan 2013  ODI # 3316  Pakistan           7
# 3   6 Jan 2013  ODI # 3316     India           6
# 4  11 Jan 2013  ODI # 3317  SriLanka           8

# %%
india=odi_match_total[odi_match_total['Country']=="India"]

# %%
india
# Out:
#       Unnamed: 0  Score  Overs   RPO  Target  Inns Result   Opposition  \
# 1            680    165   48.0  3.43   251.0     2   lost   v Pakistan
# 3            681    167   43.4  3.82     NaN     1    won   v Pakistan
# 6            682  316/9   50.0  6.32   326.0     2   lost    v England
# 10           683  285/6   50.0  5.70     NaN     1    won    v England
# 14           684  157/3   28.1  5.57   156.0     2    won    v England
# ...          ...    ...    ...   ...     ...   ...    ...          ...
# 1239         831  240/4   48.2  4.96   237.0     2    won  v Australia
# 1246         832    250   48.2  5.17     NaN     1    won  v Australia
# 1251         833    281   48.2  5.81   314.0     2   lost  v Australia
# 1254         834  358/9   50.0  7.16     NaN     1   lost  v Australia
# 1258         835    237   50.0  4.74   273.0     2   lost  v Australia
#
#                   Ground   Start Date    Match_ID Country  Country_ID
# ...

# %%
india_win=india[india['Result']=="won"]

# %%
india_win
# Out:
#       Unnamed: 0  Score  Overs   RPO  Target  Inns Result      Opposition  \
# 3            681    167   43.4  3.82     NaN     1    won      v Pakistan
# 10           683  285/6   50.0  5.70     NaN     1    won       v England
# 14           684  157/3   28.1  5.57   156.0     2    won       v England
# 24           685  258/5   47.3  5.43   258.0     2    won       v England
# 81           687  331/7   50.0  6.62     NaN     1    won  v South Africa
# ...          ...    ...    ...   ...     ...   ...    ...             ...
# 1212         827  324/4   50.0  6.48     NaN     1    won   v New Zealand
# 1216         828  245/3   43.0  5.69   244.0     2    won   v New Zealand
# 1222         830    252   49.5  5.05     NaN     1    won   v New Zealand
# 1239         831  240/4   48.2  4.96   237.0     2    won     v Australia
# 1246         832    250   48.2  5.17     NaN     1    won     v Australia
#
#                   Ground   Start Date    Match_ID Country  Country_ID
# ...

# %%
india_win['Opposition'].value_counts()
# Out:
# Opposition
# v Sri Lanka       15
# v West Indies     13
# v Zimbabwe        12
# v Australia       12
# v England         10
# v South Africa    10
# v New Zealand      9
# v Bangladesh       8
# v Pakistan         6
# v Afghanistan      1
# v U.A.E.           1
# v Ireland          1
# v Hong Kong        1
# Name: count, dtype: int64

# %%
india_win['Opposition'].value_counts()[0:5]
# Out:
# Opposition
# v Sri Lanka      15
# v West Indies    13
# v Zimbabwe       12
# v Australia      12
# v England        10
# Name: count, dtype: int64

# %%
india_win['Opposition'].value_counts()[0:5].keys()
# Out:
# Index(['v Sri Lanka', 'v West Indies', 'v Zimbabwe', 'v Australia',
#        'v England'],
#       dtype='object', name='Opposition')

# %%
from matplotlib import pyplot as plt

# %%
plt.figure(figsize=(7,4))
plt.bar(list(india_win['Opposition'].value_counts()[0:5].keys()),list(india_win['Opposition'].value_counts()[0:5]),color="y")
plt.show()

# %%
india_loss=india[india['Result']=="lost"]

# %%
india_loss
# Out:
#       Unnamed: 0  Score  Overs   RPO  Target  Inns Result      Opposition  \
# 1            680    165   48.0  3.43   251.0     2   lost      v Pakistan
# 6            682  316/9   50.0  6.32   326.0     2   lost       v England
# 28           686    226   49.4  4.55     NaN     1   lost       v England
# 113          692  229/7   50.0  4.58     NaN     1   lost   v West Indies
# 115          693    187   44.5  4.17   349.0     2   lost     v Sri Lanka
# 164          702    232   49.4  4.67   305.0     2   lost     v Australia
# 168          704  303/9   50.0  6.06     NaN     1   lost     v Australia
# 201          709  288/7   50.0  5.76     NaN     1   lost   v West Indies
# 211          711    217   41.0  5.29   359.0     2   lost  v South Africa
# 213          712    146   35.1  4.15   281.0     2   lost  v South Africa
# 239          714    268   48.4  5.50   293.0     2   lost   v New Zealand
# 243          715  277/9   41.3  6.67   293.0     2   lost   v New Zealand
# ...

# %%
india_loss['Opposition'].value_counts()
# Out:
# Opposition
# v Australia       13
# v England          8
# v New Zealand      8
# v South Africa     6
# v West Indies      5
# v Sri Lanka        4
# v Pakistan         3
# v Bangladesh       2
# Name: count, dtype: int64

# %%
plt.figure(figsize=(7,4))
plt.bar(list(india_loss['Opposition'].value_counts()[0:4].keys()),list(india_loss['Opposition'].value_counts()[0:4]),color="g")
plt.show()

# %%
#making a pie chart
plt.figure(figsize=(7,4))
plt.pie(list(india_loss['Opposition'].value_counts()),labels=list(india_loss['Opposition'].value_counts().keys()),autopct='%0.1f%%')
plt.show()

# %%
#Australia analysis

# %%
Australia=odi_match_total[odi_match_total['Country']=='Australia']

# %%
Australia
# Out:
#       Unnamed: 0  Score  Overs   RPO  Target  Inns Result   Opposition  \
# 5           1076  305/5   50.0  6.10     NaN     1    won  v Sri Lanka
# 9           1077    170   46.5  3.62     NaN     1   lost  v Sri Lanka
# 13          1078     74   26.4  2.77     NaN     1   lost  v Sri Lanka
# 19          1079  222/9   50.0  4.44     NaN     1    n/r  v Sri Lanka
# 23          1080  247/5   50.0  4.94     NaN     1    won  v Sri Lanka
# ...          ...    ...    ...   ...     ...   ...    ...          ...
# 1265        1202  281/2   49.0  5.73   281.0     2    won   v Pakistan
# 1267        1203  285/2   47.5  5.95   285.0     2    won   v Pakistan
# 1269        1204  266/6   50.0  5.32     NaN     1    won   v Pakistan
# 1271        1205  277/7   50.0  5.54     NaN     1    won   v Pakistan
# 1273        1206  327/7   50.0  6.54     NaN     1    won   v Pakistan
#
#            Ground   Start Date    Match_ID    Country  Country_ID
# ...

# %%
Australia_wins=Australia[Australia['Result']=='won']

# %%
Australia_wins
# Out:
#       Unnamed: 0  Score  Overs   RPO  Target  Inns Result     Opposition  \
# 5           1076  305/5   50.0  6.10     NaN     1    won    v Sri Lanka
# 23          1080  247/5   50.0  4.94     NaN     1    won    v Sri Lanka
# 31          1081   71/1    9.2  7.60    71.0     2    won  v West Indies
# 33          1082  266/7   50.0  5.32     NaN     1    won  v West Indies
# 35          1083  329/7   50.0  6.58     NaN     1    won  v West Indies
# ...          ...    ...    ...   ...     ...   ...    ...            ...
# 1265        1202  281/2   49.0  5.73   281.0     2    won     v Pakistan
# 1267        1203  285/2   47.5  5.95   285.0     2    won     v Pakistan
# 1269        1204  266/6   50.0  5.32     NaN     1    won     v Pakistan
# 1271        1205  277/7   50.0  5.54     NaN     1    won     v Pakistan
# 1273        1206  327/7   50.0  6.54     NaN     1    won     v Pakistan
#
#            Ground   Start Date    Match_ID    Country  Country_ID
# ...

# %%
Australia_wins['Opposition'].value_counts()
# Out:
# Opposition
# v England         14
# v India           13
# v Pakistan        13
# v West Indies      8
# v Sri Lanka        7
# v South Africa     7
# v New Zealand      5
# v Scotland         2
# v Ireland          2
# v Zimbabwe         1
# v Afghanistan      1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(7,4))
plt.bar(list(Australia_wins['Opposition'].value_counts()[0:4].keys()),list(Australia_wins['Opposition'].value_counts()[0:4]),color="g")
plt.show()

# %%
plt.figure(figsize=(7,4))
plt.pie(list(Australia_wins['Opposition'].value_counts()),labels=list(Australia_wins['Opposition'].value_counts().keys()),autopct='%0.1f%%')
plt.show()

# %%
Australia_loss=Australia[Australia['Result']=='lost']

# %%
Australia_loss
# Out:
#       Unnamed: 0  Score  Overs   RPO  Target  Inns Result      Opposition  \
# 9           1077    170   46.5  3.62     NaN     1   lost     v Sri Lanka
# 13          1078     74   26.4  2.77     NaN     1   lost     v Sri Lanka
# 85          1086  221/9   50.0  4.42   270.0     2   lost       v England
# 103         1088    233   42.3  5.48   254.0     2   lost     v Sri Lanka
# 159         1092    227   48.2  4.69     NaN     1   lost       v England
# 167         1095  359/5   50.0  7.18     NaN     1   lost         v India
# 175         1098  350/6   50.0  7.00     NaN     1   lost         v India
# 183         1099    326   45.1  7.21   384.0     2   lost         v India
# 245         1103    259   47.4  5.43   317.0     2   lost       v England
# 334         1106  327/7   50.0  6.54     NaN     1   lost  v South Africa
# 342         1107  209/9   50.0  4.18     NaN     1   lost      v Zimbabwe
# 351         1109  217/9   50.0  4.34     NaN     1   lost  v South Africa
# ...

# %%
Australia_loss['Opposition'].value_counts()
# Out:
# Opposition
# v England         15
# v India           12
# v South Africa    11
# v New Zealand      5
# v Sri Lanka        4
# v Zimbabwe         1
# v West Indies      1
# v Pakistan         1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(7,4))
plt.bar(list(Australia_loss['Opposition'].value_counts()[0:4].keys()),list(Australia_loss['Opposition'].value_counts()[0:4]),color="b")
plt.show()

# %%
plt.figure(figsize=(7,4))
plt.pie(list(Australia_loss['Opposition'].value_counts()),labels=list(Australia_loss['Opposition'].value_counts().keys()),autopct='%0.1f%%')
plt.show()

# %%
England=odi_match_total[odi_match_total['Country']=='England']

# %%
England
# Out:
#       Unnamed: 0  Score  Overs   RPO  Target  Inns Result  Opposition  \
# 7            836  325/4   50.0  6.50     NaN     1    won     v India
# 11           837    158   36.0  4.38   286.0     2   lost     v India
# 15           838    155   42.2  3.66     NaN     1   lost     v India
# 25           839  257/7   50.0  5.14     NaN     1   lost     v India
# 29           840  227/3   47.2  4.79   227.0     2    won     v India
# ...          ...    ...    ...   ...     ...   ...    ...         ...
# 1279         976    DNB    0.0     -     NaN     0    n/r  v Pakistan
# 1283         977  373/3   50.0  7.46     NaN     1    won  v Pakistan
# 1287         978  359/4   44.5  8.00   359.0     2    won  v Pakistan
# 1292         979  341/7   49.3  6.88   341.0     2    won  v Pakistan
# 1295         980  351/9   50.0  7.02     NaN     1      -  v Pakistan
#
#            Ground   Start Date    Match_ID  Country  Country_ID
# ...

# %%
England_wins=England[England['Result']=='won']

# %%
England_wins
# Out:
#       Unnamed: 0  Score  Overs   RPO  Target  Inns Result     Opposition  \
# 7            836  325/4   50.0  6.50     NaN     1    won        v India
# 29           840  227/3   47.2  4.79   227.0     2    won        v India
# 43           842  270/2   47.4  5.66   270.0     2    won  v New Zealand
# 46           843  186/5   37.3  4.96   186.0     2    won  v New Zealand
# 79           846  287/6   50.0  5.74     NaN     1    won  v New Zealand
# ...          ...    ...    ...   ...     ...   ...    ...            ...
# 1236         973  418/6   50.0  8.36     NaN     1    won  v West Indies
# 1274         975  199/6   42.0  4.73   199.0     2    won      v Ireland
# 1283         977  373/3   50.0  7.46     NaN     1    won     v Pakistan
# 1287         978  359/4   44.5  8.00   359.0     2    won     v Pakistan
# 1292         979  341/7   49.3  6.88   341.0     2    won     v Pakistan
#
#                  Ground   Start Date    Match_ID  Country  Country_ID
# ...

# %%
England_wins['Opposition'].value_counts()
# Out:
# Opposition
# v Australia       15
# v New Zealand     11
# v West Indies     11
# v Sri Lanka       10
# v Pakistan        10
# v India            8
# v South Africa     5
# v Ireland          4
# v Bangladesh       3
# v Scotland         2
# v Afghanistan      1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(7,4))
plt.bar(list(England_wins['Opposition'].value_counts()[0:4].keys()),list(England_wins['Opposition'].value_counts()[0:4]),color="b")
plt.show()

# %%
plt.figure(figsize=(7,4))
plt.pie(list(England_wins['Opposition'].value_counts()),labels=list(England_wins['Opposition'].value_counts().keys()),autopct='%0.1f%%')
plt.show()

# %%
England_loss=England[England['Result']=='lost']

# %%
England_loss
# Out:
#       Unnamed: 0  Score  Overs   RPO  Target  Inns Result      Opposition  \
# 11           837    158   36.0  4.38   286.0     2   lost         v India
# 15           838    155   42.2  3.66     NaN     1   lost         v India
# 25           839  257/7   50.0  5.14     NaN     1   lost         v India
# 41           841    258   49.3  5.21     NaN     1   lost   v New Zealand
# 75           844  227/9   50.0  4.54     NaN     1   lost   v New Zealand
# 77           845    273   44.1  6.18   360.0     2   lost   v New Zealand
# 95           848  293/7   50.0  5.86     NaN     1   lost     v Sri Lanka
# 109          851  124/8   20.0  6.20   130.0     2   lost         v India
# 154          853    227   44.2  5.12   316.0     2   lost     v Australia
# 160          856    249   48.0  5.18   299.0     2   lost     v Australia
# 234          857  269/7   50.0  5.38     NaN     1   lost     v Australia
# 236          858  300/8   50.0  6.00     NaN     1   lost     v Australia
# ...

# %%
England_loss['Opposition'].value_counts()
# Out:
# Opposition
# v Australia       14
# v Sri Lanka       11
# v India           10
# v New Zealand      8
# v South Africa     4
# v West Indies      3
# v Pakistan         3
# v Bangladesh       2
# v Scotland         1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(7,4))
plt.bar(list(England_loss['Opposition'].value_counts()[0:4].keys()),list(England_loss['Opposition'].value_counts()[0:4]),color="b")
plt.show()

# %%
plt.figure(figsize=(7,4))
plt.pie(list(England_loss['Opposition'].value_counts()),labels=list(England_loss['Opposition'].value_counts().keys()),autopct='%0.1f%%')
plt.show()

# %%
import numpy as np

# %%
England_overs=England[England['Overs']==47.5]

# %%
England_scores
# Out:
#       Unnamed: 0  Score  Overs   RPO  Target  Inns Result     Opposition  \
# 7            836  325/4   50.0  6.50     NaN     1    won        v India
# 25           839  257/7   50.0  5.14     NaN     1   lost        v India
# 29           840  227/3   47.2  4.79   227.0     2    won        v India
# 41           841    258   49.3  5.21     NaN     1   lost  v New Zealand
# 43           842  270/2   47.4  5.66   270.0     2    won  v New Zealand
# ...          ...    ...    ...   ...     ...   ...    ...            ...
# 1232         971    263   47.4  5.51   290.0     2   lost  v West Indies
# 1236         973  418/6   50.0  8.36     NaN     1    won  v West Indies
# 1283         977  373/3   50.0  7.46     NaN     1    won     v Pakistan
# 1292         979  341/7   49.3  6.88   341.0     2    won     v Pakistan
# 1295         980  351/9   50.0  7.02     NaN     1      -     v Pakistan
#
#            Ground   Start Date    Match_ID  Country  Country_ID
# ...

# %%
england_overs_table = England.groupby('Overs').size().reset_index(name='Count')
england_overs_table = england_overs_table.sort_values('Overs')
print(england_overs_table)
# Out:
#     Overs  Count
# 0     0.0      3
# 1     2.2      1
# 2     4.0      1
# 3    12.1      1
# 4    15.0      1
# ..    ...    ...
# 64   49.1      1
# 65   49.3      5
# 66   49.4      2
# 67   49.5      2
# 68   50.0     50
#
# [69 rows x 2 columns]

# %%
specific_overs = [47.5, 50.0]
filtered_table = England[England['Overs'].isin(specific_overs)]
print(filtered_table)
# Out:
#       Unnamed: 0  Score  Overs   RPO  Target  Inns Result      Opposition  \
# 7            836  325/4   50.0  6.50     NaN     1    won         v India
# 25           839  257/7   50.0  5.14     NaN     1   lost         v India
# 75           844  227/9   50.0  4.54     NaN     1   lost   v New Zealand
# 79           846  287/6   50.0  5.74     NaN     1    won   v New Zealand
# 84           847  269/6   50.0  5.38     NaN     1    won     v Australia
# 95           848  293/7   50.0  5.86     NaN     1   lost     v Sri Lanka
# 234          857  269/7   50.0  5.38     NaN     1   lost     v Australia
# 236          858  300/8   50.0  6.00     NaN     1   lost     v Australia
# 240          859  243/9   50.0  4.86     NaN     1   lost     v Australia
# 244          860  316/8   50.0  6.32     NaN     1    won     v Australia
# 270          862  254/6   50.0  5.08   270.0     2   lost   v West Indies
# 284          864  303/6   50.0  6.06     NaN     1    won   v West Indies
# ...

# %%
for over in sorted(England['Overs'].unique()):
    print(f"\n=== England Overs: {over} ===")
    print(England[England['Overs'] == over])
# Out:
# === England Overs: 0.0 ===
#       Unnamed: 0 Score  Overs RPO  Target  Inns Result     Opposition  \
# 547          893   DNB    0.0   -     NaN     0    n/r      v Ireland
# 1234         972   DNB    0.0   -     NaN     0    n/r  v West Indies
# 1279         976   DNB    0.0   -     NaN     0    n/r     v Pakistan
#
#                  Ground   Start Date    Match_ID  Country  Country_ID
# 547   Dublin (Malahide)   8 May 2015  ODI # 3650  England           1
# 1234        St George's  25 Feb 2019  ODI # 4098  England           1
# 1279           The Oval   8 May 2019  ODI # 4130  England           1
#
# === England Overs: 2.2 ===
#      Unnamed: 0 Score  Overs   RPO  Target  Inns Result     Opposition  \
# 961         942  21/0    2.2  9.00     NaN     1    n/r  v West Indies
#
#          Ground   Start Date    Match_ID  Country  Country_ID
# 961  Nottingham  21 Sep 2017  ODI # 3913  England           1
#
# === England Overs: 4.0 ===
# ...

# %%
England_score=England[England['Score']=='325']

# %%
England_score
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Score, Overs, RPO, Target, Inns, Result, Opposition, Ground, Start Date, Match_ID, Country, Country_ID]
# Index: []

# %%
overs = [20,26,36,38,47,48,50]
score = [158, 155, 273, 227, 249, 212, 99]

plt.plot(overs, score, marker='o', linestyle='-')
plt.xlabel("Overs")
plt.ylabel("Score")
plt.title("Cricket Score Progress")
plt.grid(True)  # Optional: Add a grid for better readability
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[108], line 4
#       1 overs = [20,26,36,38,47,48,50]
#       2 score = [99,155,158,227,249,273]
# ----> 4 plt.plot(overs, score, marker='o', linestyle='-')
#       5 plt.xlabel("Overs")
#       6 plt.ylabel("Score")
#
# File /opt/anaconda3/lib/python3.11/site-packages/matplotlib/pyplot.py:3578, in plot(scalex, scaley, data, *args, **kwargs)
#    3570 @_copy_docstring_and_deprecators(Axes.plot)
#    3571 def plot(
#    3572     *args: float | ArrayLike | str,
#    (...)
#    3576     **kwargs,
#    3577 ) -> list[Line2D]:
# -> 3578     return gca().plot(
#    3579         *args,
#    3580         scalex=scalex,
#    3581         scaley=scaley,
#    3582         **({"data": data} if data is not None else {}),
#    3583         **kwargs,
#    3584     )
#
# ...
